# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii

# %% [markdown]
# ## Read in Results:

# %%
file='Results.csv'
data = ascii.read(file,format='csv')
#file2='datalteff.csv'
#data2 = ascii.read(file2,format='csv')

# %% [markdown]
# ## HR Diagram:

# %%
logTeff = np.log10(data['Teff'])
logL = data['lg_L']

plt.figure()

#Model data:
plt.plot(logTeff,logL, label = 'original model')
plt.scatter(logTeff,logL)

#Homology relation #1:
x = np.linspace(3,6,100)

slope = 284/69 #71/12. # This should be the exponent of the homology relationship
offset1 = -15.5 #You can set this to whatever to move the line close to your model data.
y1 = slope*x+offset1 # This is just linear because we are ploting log-log

#plt.plot(x,y,color='r')

slope = 60/7. #15 # This should be the exponent of the homology relationship
offset2 = -34 #You can set this to whatever to move the line close to your model data.
y2 = slope*x+offset2 # This is just linear because we are ploting log-log

slope = 80. # This should be the exponent of the homology relationship
offset3 = -150 #You can set this to whatever to move the line close to your model data.
y3 = slope*x+offset3 # This is just linear because we are ploting log-log

plt.plot(x,y1,'r',label='LMS')
         
plt.plot(x,y2,'k',label = 'HMS-gas')
plt.plot(x,y3,'m',label ='HMS-rad')

plt.xlabel('Log(Teff)')
plt.ylabel('Log(L/Lsun)')
plt.legend()
plt.xlim(5.0,3.0)
plt.ylim(-10,10)
#plt.show()
plt.savefig('ques3a.pdf')

# %% [markdown]
# ## Mass-Radius

# %%
logM = np.log10(data['Mass'])
logR = data['lg_R']

plt.figure()

#Model data:
plt.plot(logR,logM)
plt.scatter(logR,logM)

#Homology relation #1:
x = np.linspace(3,6,100)

slope = 18./40
offset = -3 #You can set this to whatever to move the line close to your model data.
y = slope*x+offset # This is just linear because we are ploting log-log

plt.plot(x,y,color='r')

plt.xlabel('Log(Radius)')
plt.ylabel('Log(Mass)')
#plt.xlim(-1,2)
#plt.ylim(-1,5)
plt.show()

# %%
logM = np.log10(data['Mass'])
logL = data['lg_L']

plt.figure()

#Model data:
plt.plot(logM,logL)
plt.scatter(logM,logL)

#Homology relation #1:
x = np.linspace(3,6,100)

slope = 5# This shssh -X kalexand@login.aoc.nrao.edu ould be the exponent of the homology relationship
offset = -10 #You can set this to whatever to move the line close to your model data.
y = slope*x+offset # This is just linear because we are ploting log-log

plt.plot(x,y,color='r')

plt.ylabel('Log(Luminosity)')
plt.xlabel('Log(Mass)')
plt.xlim(-1,2.5)
plt.ylim(-2,8)
plt.show()

# %%
logM = np.log10(data['Mass'])
logTc = data['lg_Tcntr']

plt.figure()

#Model data:
plt.plot(logM,logTc, label ='original model')
plt.scatter(logM,logTc)

#Homology relation #1:
x = np.linspace(-1,6,10)

slope = 12/13# This shssh -X kalexand@login.aoc.nrao.edu ould be the exponent of the homology relationship
offset1 =7.15 #You can set this to whatever to move the line close to your model data.
y1 = slope*x+offset1 # This is just linear because we are ploting log-log

slope = 1/5. # This should be the exponent of the homology relationship
offset2 = 7.3 #You can set this to whatever to move the line close to your model data.
y2 = slope*x+offset2 # This is just linear because we are ploting log-log

slope = 1/40. # This should be the exponent of the homology relationship
offset3 = 7.5 #You can set this to whatever to move the line close to your model data.
y3 = slope*x+offset3 # This is just linear because we are ploting log-log

plt.plot(x,y1,'r',label='LMS')
         
plt.plot(x,y2,'k',label = 'HMS-gas')
plt.plot(x,y3,'m',label ='HMS-rad')

#plt.plot(x,y,color='r')

plt.ylabel('Log (Tcore)')
plt.xlabel('Log (Mass)')
plt.legend()
plt.xlim(-1,2.5)
plt.ylim(6,8)
#plt.show()
plt.savefig('ques3b.pdf')

# %%
logM = np.log10(data['Mass'])
logPc = data['lg_P_cntr']

plt.figure()

#Model data:
plt.plot(logM,logPc)
plt.scatter(logM,logPc)

#Homology relation #1:
x = np.linspace(3,6,100)

slope = 5# This shssh -X kalexand@login.aoc.nrao.edu ould be the exponent of the homology relationship
offset = -10 #You can set this to whatever to move the line close to your model data.
y = slope*x+offset # This is just linear because we are ploting log-log

plt.plot(x,y,color='r')

plt.ylabel('Log (Pcore)')
plt.xlabel('Log (Mass)')
plt.xlim(-1,2.5)
plt.ylim(14,20)
plt.show()

# %%
logM = np.log10(data['Mass'])
logt = np.log10(data['age_yr2'] - data['age_yr'])

plt.figure()

#Model data:
plt.plot(logM,logt, label = 'original model')
plt.scatter(logM,logt)

#Homology relation #1:
x = np.linspace(-1,5)

slope = -4.3# This shssh -X kalexand@login.aoc.nrao.edu ould be the exponent of the homology relationship
offset1 = 10 #You can set this to whatever to move the line close to your model data.
y1 = slope*x+offset1 # This is just linear because we are ploting log-log

slope = -2. # This should be the exponent of the homology relationship
offset2 = 9.2 #You can set this to whatever to move the line close to your model data.
y2 = slope*x+offset2 # This is just linear because we are ploting log-log

slope = 0 # This should be the exponent of the homology relationship
offset3 = 8.5 #You can set this to whatever to move the line close to your model data.
y3 = slope*x+offset3 # This is just linear because we are ploting log-log

plt.plot(x,y1,'r',label='LMS')
         
plt.plot(x,y2,'k',label = 'HMS-gas')
plt.plot(x,y3,'m',label ='HMS-rad')

#plt.plot(x,y,color='r')

plt.ylabel('Log (main sequence life time)')
plt.xlabel('Log (Mass)')
plt.legend()
plt.xlim(-1,3)
plt.ylim(2,15)
#plt.show()
plt.savefig('ques3c.pdf')
# Out:
# /home/ibik/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10
#
# /home/ibik/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log10

# %%
logTeff = np.log10(data['Teff'])
logL = data['lg_L']

plt.figure()

#Model data:
plt.plot(logTeff,logL, label ='original model')
plt.scatter(logTeff,logL)
plt.plot(np.log10(4.9e4),4.67, 'ko',label = '8 solar masses')
plt.plot(np.log10(6.18e4),5.575, 'r*',label = '22 solar masses')
plt.plot(np.log10(6.466e4),6.077, 'b^',label = '45 solar masses')
plt.xlabel('Log(Teff)')
plt.ylabel('Log(L/Lsun)')
plt.legend()
plt.xlim(5.0,3.0)
plt.ylim(-10,10)
#plt.show()
plt.savefig('ques3e.pdf')

# %%
logTeff = np.log10(data1['Teff'])
logL = data1['lg_L']


luminosity =np.log10(data2['lum_val'])
teff = (data2['logteff'])
plt.figure()
plt.plot(teff,luminosity,'k.', markersize=2,label ='gaia stars')
#plt.xlim(3.85,3.50)
#Model data:
plt.plot(logTeff,logL, label ='original model')
plt.scatter(logTeff,logL)
plt.plot(np.log10(4.9e4),4.67, 'ko',label = '8 solar masses')
plt.plot(np.log10(6.18e4),5.575, 'r*',label = '22 solar masses')
plt.plot(np.log10(6.466e4),6.077, 'b^',label = '45 solar masses')
plt.xlabel('Log(Teff)')
plt.ylabel('Log(L/Lsun)')
plt.legend()
plt.xlim(5.0,3.0)
plt.ylim(-2,7)
#plt.show()
plt.savefig('ques3f.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-17ad6b22a6f7> in <module>
# ----> 1 logTeff = np.log10(data1['Teff'])
#       2 logL = data1['lg_L']
#       3
#       4
#       5 luminosity =np.log10(data2['lum_val'])
#
# NameError: name 'data1' is not defined
