# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('/home/ibik/Documents/sndata/snradio1.csv') #reads in the upperlimit data parameters
df2 = pd.read_csv('/home/ibik/Documents/sndata/sndetec.csv') #reads in the detected Luminosity data parameters
df3 = pd.read_csv('/home/ibik/Documents/sndata/radiomodel.csv') # reads in the radio model for testing data parameters
df4 = pd.read_csv('/home/ibik/Documents/sndata/othersne.csv') #reads in the other SNe data parameters


#excel_file = 'snradio1.xls'

#snradio = pd.read_excel(excel_file)dfa137 = pd.read_csv('/home/ibik/Documents/sndata/a137.csv')

# %%
df1.columns=['','Target', 'Obs. Date (MJD)','date of g-max', 'days', 'redshift', 'D(luminosity)', 'Flux/upper limits', 'Radioluminosity','logl','restdays']
df2.columns=['','Target', 'Obs. Date (MJD)','date of g-max', 'days', 'redshift', 'D(luminosity)', 'Flux/upper limits', 'Radioluminosity','logl','restdays']
df3.columns=['Astar','Time','Luminosity','logl']
df4.columns=['SN','time','DL','Flux(Jy)', 'Luminosity(erg/s/Hz)','logl']

# %%
#df4
#df4['time'][0:5]
df4['logl'][65:66]
# Out:
# 65    30.085609
# Name: logl, dtype: float64

# %%
#this code plots the other supernovae with the observed PS1 ones
plt.figure(figsize=(20,10))
#plt.ylim(27,30.00)
#plt.xlim(250, 1750)
plt.plot(df1['restdays'], df1['logl'],'rv', markersize=15, label = 'upper limits of undetected SLSNe') # marker_color='r')
plt.plot(df2['restdays'], df2['logl'],'ko', markersize=15, label = 'detected SLSNe') # marker_color='b')
plt.plot(df4['time'][0:3], df4['logl'][0:3],'b*', markersize=15, label = 'SNso') # marker_color='b')
plt.plot(df4['time'][4:6], df4['logl'][4:6],'b.', markersize=15, label = 'SN1978g') # marker_color='b')

plt.plot(df4['time'][7:9], df4['logl'][7:9],'bh', markersize=15, label = 'SN1983k') # marker_color='b')

plt.plot(df4['time'][10:13], df4['logl'][10:13],'bP', markersize=15, label = 'SN1984E') # marker_color='b')

plt.plot(df4['time'][14:17], df4['logl'][14:17],'bp', markersize=15, label = 'SN1987F') # marker_color='b')

plt.plot(df4['time'][18:19], df4['logl'][18:19],'bs', markersize=15, label = 'SN1991ae') # marker_color='b')
plt.plot(df4['time'][20:22], df4['logl'][20:22],'bd', markersize=15, label = 'SN1991ar') # marker_color='b')

plt.plot(df4['time'][23:32], df4['logl'][23:32],'bD', markersize=15, label = 'SN2006jd') # marker_color='b')

plt.plot(df4['time'][34:48], df4['logl'][34:48],'b+', markersize=15, label = 'SN1995N') # marker_color='b')

plt.plot(df4['time'][50:54], df4['logl'][50:54],'b*', markersize=15, label = 'SN2009ip') # marker_color='b')
plt.plot(df4['time'][56:60], df4['logl'][56:60],'c.', markersize=15, label = 'SN1998S') # marker_color='b')
plt.plot(df4['time'][62:63], df4['logl'][62:63],'ch', markersize=15, label = 'SN1978K') # marker_color='b')
plt.plot(df4['time'][65:66], df4['logl'][65:66],'cp', markersize=15, label = 'SN2005kd') # marker_color='b')
plt.plot(df4['time'][67:71], df4['logl'][67:71],'cs', markersize=15, label = 'SN19986j') # marker_color='b')
plt.plot(df4['time'][73:83], df4['logl'][73:83],'c+', markersize=15, label = 'SN1988Z') # marker_color='b')
plt.plot(df4['time'][85:97], df4['logl'][85:97],'c4', markersize=15, label = 'SN1988Z') # marker_color='b')
plt.plot(df4['time'][85:97], df4['logl'][85:97],'m4', markersize=15, label = 'SN1988Z_5GHz') # marker_color='b')

plt.plot(df4['time'][99:100], df4['logl'][99:100],'m*', markersize=15, label = 'SN1997eg_5GHz') # marker_color='b')
plt.plot(df4['time'][102:108], df4['logl'][102:108],'m.', markersize=15, label = 'SN2001em') # marker_color='b')
plt.plot(df4['time'][110:115], df4['logl'][110:115],'md', markersize=15, label = 'SN2000ft_5GHz') # marker_color='b')
plt.plot(df4['time'][117:121], df4['logl'][117:121],'ms', markersize=15, label = 'SN2000ft') # marker_color='b')
plt.plot(df4['time'][123:128], df4['logl'][123:128],'mp', markersize=15, label = 'SN1996cr_5GHz') # marker_color='b')


plt.xlabel('Rest Frame Days post-explosion (days)', fontsize=14)
plt.ylabel('Log$_{10}$ Luminosity (erg $s^{-1}$ $Hz^{-1}$)', fontsize =14)
plt.legend(frameon=True, framealpha=0.1, loc='center left', bbox_to_anchor=(1, 0.5))
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.show()
plt.savefig('othersne.pdf')

# %%
#this code plots the first models for testing
plt.figure(figsize=(20,10))
plt.ylim(27,30.00)
plt.xlim(250, 1750)
plt.plot(df1['restdays'], df1['logl'],'rv', markersize=15, label = 'upper limits of undetected SLSNe') # marker_color='r')
plt.plot(df2['restdays'], df2['logl'],'ko', markersize=15, label = 'detected SLSNe') # marker_color='b')

plt.plot(df3['Time'][0:99], df3['logl'][0:99],'.-', alpha =0.5, label = 'A1') # marker_color='b')
plt.plot(df3['Time'][100:199], df3['logl'][100:199],'*-', alpha =0.5, label = 'A2')
plt.plot(df3['Time'][200:299], df3['logl'][200:299],'h-', alpha =0.5, label = 'A3')
plt.plot(df3['Time'][300:399], df3['logl'][300:399],'^-', alpha =0.5, label = 'A4')
plt.plot(df3['Time'][400:499], df3['logl'][400:499],'v-', alpha =0.5, label = 'A5')
plt.plot(df3['Time'][500:599], df3['logl'][500:599],'o-', alpha =0.5, label = 'A6')
plt.plot(df3['Time'][600:699], df3['logl'][600:699],'o-', alpha =0.5, label = 'A7')
plt.plot(df3['Time'][700:799], df3['logl'][700:799],'o-', alpha =0.5, label = 'A8')
plt.plot(df3['Time'][800:899], df3['logl'][800:899],'o-', alpha =0.5, label = 'A9')
plt.plot(df3['Time'][900:999], df3['logl'][900:999],'o-', alpha =0.5, label = 'A10')
plt.plot(df3['Time'][1000:1099], df3['logl'][1000:1099],'o-', alpha =0.5, label = 'A11')
plt.plot(df3['Time'][1100:1199], df3['logl'][1100:1199],'o-', alpha =0.5, label = 'A12')
plt.plot(df3['Time'][1200:1299], df3['logl'][1200:1299],'o-', alpha =0.5, label = 'A13')
plt.plot(df3['Time'][1300:1399], df3['logl'][1300:1399],'o-', alpha =0.5, label = 'A14')
plt.plot(df3['Time'][1400:1499], df3['logl'][1400:1499],'o-', alpha =0.5, label = 'A15')
plt.plot(df3['Time'][1500:1599], df3['logl'][1500:1599],'o-', alpha =0.5, label = 'A16')
plt.plot(df3['Time'][1600:1699], df3['logl'][1600:1699],'o-', alpha =0.5, label = 'A17')
plt.plot(df3['Time'][1700:1799], df3['logl'][1700:1799],'o-', alpha =0.5, label = 'A18')
plt.plot(df3['Time'][1800:1899], df3['logl'][1800:1899],'o-', alpha =0.5, label = 'A19')
plt.plot(df3['Time'][1900:1999], df3['logl'][1900:1999],'o-', alpha =0.5, label = 'A20')
plt.plot(df3['Time'][2000:2099], df3['logl'][2000:2099],'o-', alpha =0.5, label = 'A21')
plt.plot(df3['Time'][2100:2199], df3['logl'][2100:2199],'o-', alpha =0.5, label = 'A22')
plt.plot(df3['Time'][2200:2299], df3['logl'][2200:2299],'o-', alpha =0.5, label = 'A23')
plt.plot(df3['Time'][2300:2399], df3['logl'][2300:2399],'o-', alpha =0.5, label = 'A24')
plt.plot(df3['Time'][2400:2499], df3['logl'][2400:2499],'o-', alpha =0.5, label = 'A25')
plt.plot(df3['Time'][2500:2599], df3['logl'][2500:2599],'o-', alpha =0.5, label = 'A26')
plt.plot(df3['Time'][2600:2699], df3['logl'][2600:2699],'o-', alpha =0.5, label = 'A27')
plt.plot(df3['Time'][2700:2799], df3['logl'][2700:2799],'o-', alpha =0.5, label = 'A28')
plt.plot(df3['Time'][2800:2899], df3['logl'][2800:2899],'o-', alpha =0.5, label = 'A29')
plt.plot(df3['Time'][2900:2999], df3['logl'][2900:2999],'o-', alpha =0.5, label = 'A30')


plt.xlabel('Rest Frame Days post-explosion (days)', fontsize=14)
plt.ylabel('Log$_{10}$ Luminosity (erg $s^{-1}$ $Hz^{-1}$)', fontsize =14)
plt.legend(frameon=True, framealpha=0.1, loc='center left', bbox_to_anchor=(1, 0.5))
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.show()
plt.savefig('test1.pdf')

# %%
plt.savefig('snr2.pdf')
